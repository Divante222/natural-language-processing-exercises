# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd

import os
from pprint import pprint

# %%
headers = {"User-Agent": "Chrome/91.0.4472.124"}



url = 'https://codeup.com/blog/'
response = get(url, headers = headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
article_links = soup.find_all('a')

# %%
the_list = []

for element in article_links:
    try:
        if 'http' in element['href']:
            the_list.append(element['href'])
    except:
        continue
    
the_list
# Out:
# ['https://codeup.com/',
#  'https://codeup.com/program/cloud-adminsitration/',
#  'https://codeup.com/program/full-stack-web-development/',
#  'https://codeup.com/program/data-science/',
#  'https://codeup.com/financial-aid/',
#  'https://codeup.com/veterans/',
#  'https://codeup.com/hire-tech-talent/',
#  'https://alumni.codeup.com/',
#  'https://codeup.com/resources/',
#  'https://codeup.com/blog/',
#  'https://codeup.com/frequently-asked-questions/',
#  'https://codeup.com/podcast/',
#  'https://codeup.com/apply-now/',
#  'https://codeup.com/',
#  'https://codeup.com/programs/',
#  'https://codeup.com/program/data-science/',
#  'https://codeup.com/program/cloud-administration/',
#  'https://codeup.com/program/full-stack-web-development/',
#  'https://codeup.com/events/',
#  'https://codeup.com/blog/',
#  'https://codeup.com/san-antonio/',
#  'https://codeup.com/dallas/',
#  'https://codeup.com/hire-tech-talent/',
#  'https://codeup.com/hire-tech-talent/',
# ...

# %%
def codeup_blog_posts():

    headers = {"User-Agent": "Chrome/91.0.4472.124"}
    url = 'https://codeup.com/blog/'
    response = get(url, headers = headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    article_links = soup.find_all('h2', class_="entry-title")
    value_list = []
    the_dict = {}
    title_list = []
    for i in range(len(article_links)):
        list_to_append = []
        url = article_links[i].find_all('a')[0]['href']
        response = get(url, headers = headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        response = get(url, headers = headers)
        key = soup.find_all('h1')[0].text
        title_list.append(key)
        value = soup.find_all('div', class_ = 'entry-content')[0].find_all('p')
        titles_list = []
        for j in value:

            list_to_append.append(j.text)
            
        
        
        value_list.append(str(list_to_append))    
        the_dict[key] = value_list
        
    the_df = pd.concat([pd.DataFrame(value_list, columns = ['content']),pd.DataFrame(title_list, columns = ['title'])], axis = 1)
    
    return the_df

# %%
codeup_blog_posts()
# Out:
#                                              content  \
# 0  ['May is traditionally known as Asian American...
# 1  ['Codeup is hosting a Women in Tech Panel in h...
# 2  ['Codeup is hosting a Women in Tech Panel in h...
# 3  ['Codeup is hosting a Women in Tech Panel in h...
# 4  ['Codeup is hosting a Women in Tech Panel in h...
# 5  ['', 'Codeup is hosting a Black Excellence in ...
#
#                                                title
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...

# %%
headers = {"User-Agent": "Chrome/91.0.4472.124"}
url = 'https://codeup.com/blog/'
response = get(url, headers = headers)
soup = BeautifulSoup(response.content, 'html.parser')

article_links = soup.find_all('h2', class_="entry-title")
# print(article_links[1].find_all('a')[0]['href'])
value_list = []
the_dict = {}
for i in range(len(article_links)):
    url = article_links[i].find_all('a')[0]['href']
    response = get(url, headers = headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    response = get(url, headers = headers)
    key = soup.find_all('h1')[0].text
    
    value = soup.find_all('div', class_ = 'entry-content')[0].find_all('p')
    for j in value:

        value_list.append(j.text)

    the_dict[key] = value_list
    value_list = []

        
pd.DataFrame([the_dict])
# Out:
#   Spotlight on APIDA Voices: Celebrating Heritage and Inspiring Change ft. Arbeena Thapa  \
# 0  [May is traditionally known as Asian American ...
#
#   Women in tech: Panelist Spotlight – Magdalena Rahn  \
# 0  [Codeup is hosting a Women in Tech Panel in ho...
#
#   Women in tech: Panelist Spotlight – Rachel Robbins-Mayhill  \
# 0  [Codeup is hosting a Women in Tech Panel in ho...
#
#     Women in Tech: Panelist Spotlight – Sarah Mellor  \
# 0  [Codeup is hosting a Women in Tech Panel in ho...
#
#   Women in Tech: Panelist Spotlight – Madeleine Capper  \
# 0  [Codeup is hosting a Women in Tech Panel in ho...
#
#   Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia
# 0  [, Codeup is hosting a Black Excellence in Tec...

# %%
def get_info(url, find_all):
    headers = {"User-Agent": "Chrome/91.0.4472.124"}
    response = get(url, headers = headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    article_links = soup.find_all(find_all) 
    return article_links

# %%
def get_blog_articles():
    url = 'https://codeup.com/blog/'
    article_links = get_info(url, 'a')
    
    
    the_list = []

    for element in article_links:
        try:
            if 'http' in element['href']:
                the_list.append(element['href'])
        except:
            continue

    article_links = get_info(url, 'div')
    
    for i in range(2,3):
        url = the_list[i]
        print(url)
        article_links = get_info(url, 'div')
        for element in article_links:
            print(element)

# %%
get_blog_articles()
# Out:
# https://codeup.com/program/full-stack-web-development/
# <div class="divi-mobile-menu">
# <div class="menu-wrap menuclosed" id="dm_nav">
# <div class="menu-wrap__inner">
# <div class="scroll_section">
# <nav class="menu-top"></nav>
# <nav class="menu-side">
# <span class="menu-name-behind"></span>
# <ul class="nav" id="dm-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-16491"><a href="https://codeup.com/">Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-18125"><a href="https://codeup.com/program/cloud-adminsitration/">Cloud Administration</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-course current-menu-item menu-item-16497"><a aria-current="page" href="https://codeup.com/program/full-stack-web-development/">Full Stack Web Development</a></li>
# ...

# %%
def get_news_articles():
    headers = {"User-Agent": "Chrome/91.0.4472.124"}
    url_list = []
    begins_with = 'https://inshorts.com/'
    url = 'https://inshorts.com/en/read'
    response = get(url, headers = headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    # the_ul = soup.find_all('ul', class_ = 'category-list')[0].find_all('a')
    the_dict = {}
    for i in soup.find_all('ul', class_ = 'category-list')[0].find_all('a'):
        if i.text in [' Business ', ' Sports ',' Technology ', ' Entertainment ']:

            'news-card-title news-right-box'

            response2 = get(begins_with + i['href'][1:], headers = headers)
            soup2 = BeautifulSoup(response2.content, 'html.parser')
            value_list = []
            key_list = []

            for j in soup2.find_all('div', class_ = 'card-stack')[0].find_all('div', class_ = 'news-card-content'):
                value_list.append(j.text.splitlines()[1])
    #             print(j.text.splitlines()[1])

            for j in soup2.find_all('div', class_ = 'card-stack')[0].find_all('div', class_ = 'news-card-title news-right-box'):
    #             print(j.text.splitlines())
                key_list.append(j.text.splitlines()[2])

            for k in range(len(key_list)):

                the_dict[key_list[k]] = value_list[k]
        
        if i.text ==  ' Business ':   
            the_df1 = pd.DataFrame(key_list, columns = ['title'])
            the_df2 = pd.DataFrame(value_list, columns = ['content'])

            business_df = pd.concat([the_df1, the_df2], axis=1)
            business_df['catagory'] = 'Business'
            

        if i.text ==  ' Sports ':   
            the_df1 = pd.DataFrame(key_list, columns = ['title'])
            the_df2 = pd.DataFrame(value_list, columns = ['content'])

            sports_df = pd.concat([the_df1, the_df2], axis=1)
            sports_df['catagory'] = 'Sports'


        if i.text ==  ' Technology ':   
            the_df1 = pd.DataFrame(key_list, columns = ['title'])
            the_df2 = pd.DataFrame(value_list, columns = ['content'])

            tech_df = pd.concat([the_df1, the_df2], axis=1)
            tech_df['catagory'] = 'Technology'
            


        if i.text ==  ' Entertainment ':   
            the_df1 = pd.DataFrame(key_list, columns = ['title'])
            the_df2 = pd.DataFrame(value_list, columns = ['content'])

            ent_df = pd.concat([the_df1, the_df2], axis=1)
            ent_df['catagory'] = 'Entertainment'
     
    return pd.concat([ent_df, tech_df, sports_df, business_df])

# %%
df = get_news_articles()

# %%
get_news_articles()
# Out:
#                                                 title  \
# 0   If Lord Hanuman saw 'Adipurush', he'd throw a ...
# 1   I was molested by family doctor, had my Class ...
# 2   Ravan was very knowledgeable, 'Adipurush' blac...
# 3   Sunny Deol's son Karan Deol shares unseen pics...
# 4   Saif Ali Khan performed well in 'Adipurush': '...
# ..                                                ...
# 19  Piramal Enterprises to sell full stake in Shri...
# 20  IIFL Securities shares fall over 19% after SEB...
# 21  Retail inflation for farm, rural workers eases...
# 22  Zee's fundamentals worsening, SEBI order risks...
# 23  Every dollar invested in civil aviation yields...
#
#                                               content       catagory
# 0   Actor Mukesh Khanna has criticised Om Raut dir...  Entertainment
# 1   Actress Jiya Shankar said that she was moleste...  Entertainment
# 2   Ramanand Sagar's son Prem, while talking about...  Entertainment
# ...

# %%
df.to_dict()
# Out:
# {'title': {0: 'Apple could force 111-year-old Swiss firm to change its apple logo',
#   1: "Nissan's ex-CEO Carlos Ghosn sues automaker for $1 bn over ouster",
#   2: 'Financial influencer Ashesh & wife found running ₹300 cr drug racket, flee with ₹170 cr',
#   3: "Who is Shahzada Dawood, one of Pak's richest men on missing Titanic submarine?",
#   4: 'Air India signs agreement with Airbus, Boeing for 470 new aircraft',
#   5: 'Rahul Shivshankar quits as Times Now Editor-in-Chief',
#   6: 'SBI MD Swaminathan Janakiraman appointed as RBI Deputy Governor',
#   7: "Which are India's 10 most valuable listed private companies according to Hurun?",
#   8: 'AI to pave way for millions of startups, generate jobs: Airbnb CEO',
#   9: 'Hexaware Technologies to hire 5,000-6,000 people: Executive',
#   10: 'Suzuki to temporarily close car plants in Pak amid import curbs',
#   11: 'Hyundai to invest over $85 billion by 2032, boost EV production',
# ...

# %%
headers = {"User-Agent": "Chrome/91.0.4472.124"}
url_list = []
begins_with = 'https://inshorts.com/'
url = 'https://inshorts.com/en/read'
response = get(url, headers = headers)
soup = BeautifulSoup(response.content, 'html.parser')
master_list_titles = []
master_list_content =[]
master_list_catagory = []
# the_ul = soup.find_all('ul', class_ = 'category-list')[0].find_all('a')
the_dict = {}
for i in soup.find_all('ul', class_ = 'category-list')[0].find_all('a'):
    if i.text in [' Business ', ' Sports ',' Technology ', ' Entertainment ']:
        
        'news-card-title news-right-box'
        
        response2 = get(begins_with + i['href'][1:], headers = headers)
        soup2 = BeautifulSoup(response2.content, 'html.parser')
        value_list = []
        key_list = []
        
        for j in soup2.find_all('div', class_ = 'card-stack')[0].find_all('div', class_ = 'news-card-content'):
            value_list.append(j.text.splitlines()[1])
#             print(j.text.splitlines()[1])
            
        for j in soup2.find_all('div', class_ = 'card-stack')[0].find_all('div', class_ = 'news-card-title news-right-box'):
#             print(j.text.splitlines())
            key_list.append(j.text.splitlines()[2])
            
        for k in range(len(key_list)):
            
            the_dict[key_list[k]] = value_list[k]
    
    if i.text ==  ' Business ':   
        the_df1 = pd.DataFrame(key_list, columns = ['title'])
        the_df2 = pd.DataFrame(value_list, columns = ['content'])
        
        business_df = pd.concat([the_df1, the_df2], axis=1)
        business_df['catagory'] = 'Business'
        
        for l in business_df.title:
            a_dict = {}
            a_dict['title'] = l
            master_list_titles.append(a_dict)
            
        for l in business_df.content:
            a_dict = {}
            a_dict['content'] = l
            
            master_list_content.append(a_dict)
            
        for l in business_df.catagory:
            a_dict = {}
            a_dict['catagory'] = l
            
            master_list_catagory.append(a_dict)
        
    if i.text ==  ' Sports ':   
        the_df1 = pd.DataFrame(key_list, columns = ['title'])
        the_df2 = pd.DataFrame(value_list, columns = ['content'])
        
        sports_df = pd.concat([the_df1, the_df2], axis=1)
        sports_df['catagory'] = 'Sports'
        
        for l in sports_df.title:
            a_dict = {}
            a_dict['title'] = l
            master_list_titles.append(a_dict)
            
        for l in sports_df.content:
            a_dict = {}
            a_dict['content'] = l
            
            master_list_content.append(a_dict)
            
        for l in sports_df.catagory:
            a_dict = {}
            a_dict['catagory'] = l
            
            master_list_catagory.append(a_dict)
        
        
    if i.text ==  ' Technology ':   
        the_df1 = pd.DataFrame(key_list, columns = ['title'])
        the_df2 = pd.DataFrame(value_list, columns = ['content'])
        
        tech_df = pd.concat([the_df1, the_df2], axis=1)
        tech_df['catagory'] = 'Technology'
        for l in tech_df.title:
            a_dict = {}
            a_dict['title'] = l
            master_list_titles.append(a_dict)
            
        for l in tech_df.content:
            a_dict = {}
            a_dict['content'] = l
            
            master_list_content.append(a_dict)
            
        for l in tech_df.catagory:
            a_dict = {}
            a_dict['catagory'] = l
            
            master_list_catagory.append(a_dict)
                
        
        
    if i.text ==  ' Entertainment ':   
        the_df1 = pd.DataFrame(key_list, columns = ['title'])
        the_df2 = pd.DataFrame(value_list, columns = ['content'])
        
        ent_df = pd.concat([the_df1, the_df2], axis=1)
        ent_df['catagory'] = 'Entertainment'
        
        for l in ent_df.title:
            a_dict = {}
            a_dict['title'] = l
            
            master_list_titles.append(a_dict)
            
        for l in ent_df.content:
            a_dict = {}
            a_dict['content'] = l
            
            master_list_content.append(a_dict)

        for l in ent_df.catagory:
            a_dict = {}
            a_dict['catagory'] = l
            
            master_list_catagory.append(a_dict)
        
joined_list = []
master_list_titles
master_list_content
master_list_catagory
for i in range(len(master_list_titles)):
    joined_list.append([master_list_titles[i]['title'],master_list_content[i]['content'],master_list_catagory[i]['catagory']])

# %%
pd.DataFrame(joined_list)
# Out:
#                                                     0  \
# 0   Apple could force 111-year-old Swiss firm to c...
# 1   Nissan's ex-CEO Carlos Ghosn sues automaker fo...
# 2   Financial influencer Ashesh & wife found runni...
# 3   Which are India's 10 most valuable listed priv...
# 4   Who is Shahzada Dawood, one of Pak's richest m...
# ..                                                ...
# 94  God has taken his time to make him perfect: Ra...
# 95  Used to sit in gay bars: Sayani on preparing f...
# 96  Someone linked us up, there was no love angle:...
# 97  I'll launch you if you want to be actor: Kher ...
# 98  Deepika-Ranveer dance with Sunny Deol, family ...
#
#                                                     1              2
# 0   Fruit Union Suisse, a 111-year-old Swiss compa...       Business
# 1   Nissan's former CEO Carlos Ghosn has filed a $...       Business
# 2   Financial influencer Ashesh Mehta and his wife...       Business
# ...

# %%
sports_df.head()

# %%
tech_df.head()

# %%
ent_df.head()
